# %% [markdown]
# # Semester 1 Practice Final Exam - Intermediate Data Programming

# %% [markdown]
# ## Instructions:
#
# **Solutions:** An answer key is provided to check your work.
#
# **Use of Resources:** You are allowed to refer to allowed sites and your notes on the real exam. However, on the practice you can use any resources to aid your learning.

# %% [markdown]
# ## Pandas Query Related Questions
#
# For this section, you will leverage the data provided in movies.csv to perform the computations asked by the questions. All necessary import statements are provided. DO NOT import any additional libraries.

# %%
import pandas as pd



def avg_budget(df):
    '''
    Calculate and return the average budget across all movies.
    Even though there are duplicates, for this question, assume no duplicates.
    '''
    return df["Budget ($)"].mean()
    pass


def avg_budget_correct(df):
    '''
    Calculate and return the average budget across all movies and handle the fact
    that there are duplicate entries in the DataFrame.
    '''
    return df["Budget ($)"].drop_duplicates().mean() 
    pass


def count_movies(df):
    '''
    Return the count of unique movie Titles in the dataframe.
    '''
    return df["Title"].drop_duplicates().count()
    pass


def warner_universal_over_8(df):
    '''
    Filter and return the titles of movies produced by 
    Warner Bros. or Universal Studios that have a rating over 8.0 
    '''
    return df[((df["Production Company"] == "Warner Bros.") | (df["Production Company"] == "Universal Studios")) & (df["Rating"]> 8.0)]["Title"]
    pass


def actress_longer_than_6(df):
    '''
    Return a list of unique actresses that have a last name longer than 6 characters. 
    Sort the names alphabetically, by full name, in reverse. Z->A
    '''
    names = df["Actress"].drop_duplicates()
    mask = names.apply(lambda full: len(full.split()[-1]) > 6)
    result = names[mask].sort_values(ascending=False)
    return result.tolist()


def top_5_box_office(df):
    '''
    Return the top 5 movies as a Series with the highest box office earnings
    '''
    return df.nlargest(5, "Box Office ($)")["Title"]
    pass


def avg_budget_1990s(df):
    '''
    Return the average budget for movies released in the 1990s (1990-1999).
    Assure that there are no duplicates.
    '''
    df_1990s = df[(df["Year"] > 1989) & (df["Year"] < 2000)]
    return df_1990s["Budget ($)"].drop_duplicates().mean()
    pass


def box_office_per_genre(df):
    '''
    Return the total box office earnings for each genre as a Series
    '''
    return df.groupby("Genre")["Box Office ($)"].sum()
    pass


def highest_avg_director(df):
    '''
    Return the name of the director with the highest average movie rating
    '''
    df_director = df.groupby("Director")["Rating"].mean().idxmax()
    return df_director
    pass


def top_5_most_movies_by_production_company(df):
    '''
    Return the list of the top 5 production companies with the most movies
    '''
    df_companies= df["Production Company"].value_counts().nlargest(5).index.tolist()
    return df_companies 
    pass


def profit_per_movie(df):
    '''
    Calculate the profit (Box Office - Budget) for each movie and add it to a
    new column called 'Profit'. Return the new dataframe.
    '''
    df["Profit"] = df["Box Office ($)"] - df["Budget ($)"]
    return df
    pass


def blockbuster_or_flop(df):
    '''
    Classify each movie as a 'Blockbuster' if its Box Office is at least 200 
    and as a 'Flop' if its Box Office is less than 200. The new column name
    will be 'Success'. Return the new dataframe
    '''
    df["Success"] = "Flop"
    df[df["Box Office ($)"]>=200, "Success"] = "Blockbuster"
    return df


def top_5_after_2000(df):
    '''
    Return the list of Titles of the top 5 highest rated movies released after the year 2000
    '''
    masked_df = df[df["Year"]>2000]
    masked_df = masked_df.nlargest(5, "Rating")
    return masked_df["Title"].tolist()

def run_query_questions(df):
    # add code here to see results of your code
    print(avg_budget(df))
    print(top_5_after_2000(df))

run_query_questions(pd.read_csv('movies.csv'))
display(pd.read_csv('movies.csv'))
# Out:
# 60.69491525423729
# ['Interstellar', 'The Dark Knight', 'Black Panther', 'The Lord of the Rings: The Fellowship of the Ring', 'Inception']
#                                                 Title            Genre  Year  \
# 0                                    Schindler's List            Drama  1993
# 1                                          Fight Club            Drama  1999
# 2                            The Silence of the Lambs            Crime  1991
# 3                                         The Pianist        Biography  2002
# 4                                          Goodfellas            Crime  1990
# 5                                          Casablanca            Drama  1942
# 6                                               Se7en            Crime  1995
# 7                                      The Green Mile            Crime  1999
# 8                                         The Shining           Horror  1980
# 9                                     American Beauty            Drama  1999
# 10                                   A Beautiful Mind        Biography  2001
# 11                                       The Departed            Crime  2006
# 12                           The Grand Budapest Hotel           Comedy  2014
# 13                                    Pan's Labyrinth            Drama  2006
# 14                           The Shawshank Redemption            Drama  1994
# 15                                       Pulp Fiction            Crime  1994
# 16                                       Forrest Gump            Drama  1994
# 17                                         The Matrix           Sci-Fi  1999
# 18                                      Jurassic Park        Adventure  1993
# 19                 Star Wars: Episode IV - A New Hope           Sci-Fi  1977
# 20                                      The Lion King        Animation  1994
# 21                                     The Terminator           Sci-Fi  1984
# 22                                      The Godfather            Crime  1972
# 23                                       Pulp Fiction            Crime  1994
# 24                                       Forrest Gump            Drama  1994
# 25                                         The Matrix           Sci-Fi  1999
# 26                                      Jurassic Park        Adventure  1993
# 27  The Lord of the Rings: The Fellowship of the Ring        Adventure  2001
# 28                                            Titanic          Romance  1997
# 29                 Star Wars: Episode IV - A New Hope           Sci-Fi  1977
# 30                                             Avatar           Sci-Fi  2009
# 31                                      The Lion King        Animation  1994
# 32                                     The Terminator           Sci-Fi  1984
# 33                                          Gladiator           Action  2000
# 34                                       The Avengers           Action  2012
# 35                                 The Social Network            Drama  2010
# 36                                       The Revenant        Adventure  2015
# 37                                          Inception           Sci-Fi  2010
# 38              Eternal Sunshine of the Spotless Mind            Drama  2004
# 39                                           Die Hard           Action  1988
# 40                                    The Dark Knight           Action  2008
# 41                                 Mad Max: Fury Road           Action  2015
# 42                                          Gladiator           Action  2000
# 43                          Die Hard with a Vengeance           Action  1995
# 44                                      Lethal Weapon           Action  1987
# 45                                              Speed           Action  1994
# 46                                         Die Hard 2           Action  1990
# 47                                          John Wick           Action  2014
# 48                                  The Awesome Quest        Adventure  1999
# 49                                         La La Land          Romance  2016
# 50                                   Galactic Odyssey           Sci-Fi  2006
# 51                                   Secrets Unveiled          Mystery  2014
# 52                                  Courage and Honor           Action  2001
# 53                                    Melodic Harmony            Drama  2004
# 54                                           Die Hard           Action  1988
# 55                                      Comedy Frenzy           Comedy  2023
# 56                                       Interstellar  Science Fiction  2014
# 57                                   Schindler's List            Drama  1993
# 58                                      Black Panther           Action  2018
#
#                        Director  Rating  Duration (min)  Budget ($)  \
# 0              Steven Spielberg     8.9             195          22
# 1                 David Fincher     8.8             139          63
# 2                Jonathan Demme     8.6             118          19
# 3                Roman Polanski     8.5             150          35
# 4               Martin Scorsese     8.7             146          25
# 5                Michael Curtiz     8.5             102           1
# 6                 David Fincher     8.6             127          33
# 7                Frank Darabont     8.6             189          60
# 8               Stanley Kubrick     8.4             146          19
# 9                    Sam Mendes     8.3             122          15
# 10                   Ron Howard     8.2             135          58
# 11              Martin Scorsese     8.5             151          90
# 12                 Wes Anderson     8.1              99          25
# 13           Guillermo del Toro     8.2             118          19
# 14               Frank Darabont     9.3             142          25
# 15            Quentin Tarantino     8.9             154           8
# 16              Robert Zemeckis     8.8             142          55
# 17               The Wachowskis     8.7             136          63
# 18             Steven Spielberg     8.1             127          63
# 19                 George Lucas     8.6             121          11
# 20                 Roger Allers     8.5              88          45
# 21                James Cameron     8.0             107           6
# 22         Francis Ford Coppola     9.2             175           6
# 23            Quentin Tarantino     8.9             154           8
# 24              Robert Zemeckis     8.8             142          55
# 25               The Wachowskis     8.7             136          63
# 26             Steven Spielberg     8.1             127          63
# 27                Peter Jackson     8.8             178          93
# 28                James Cameron     7.8             195         200
# 29                 George Lucas     8.6             121          11
# 30                James Cameron     7.8             162         237
# 31                 Roger Allers     8.5              88          45
# 32                James Cameron     8.0             107           6
# 33                 Ridley Scott     8.5             155         103
# 34                  Joss Whedon     8.0             143         220
# 35                David Fincher     7.7             120          40
# 36  Alejandro González Iñárritu     8.0             156         135
# 37            Christopher Nolan     8.8             148         160
# 38                Michel Gondry     8.3             108          20
# 39               John McTiernan     8.2             132          28
# 40            Christopher Nolan     9.0             152         185
# 41                George Miller     8.1             120         150
# 42                 Ridley Scott     8.5             155         103
# 43               John McTiernan     7.6             128          90
# 44               Richard Donner     7.6             110          15
# 45                  Jan de Bont     7.2             116          30
# 46                 Renny Harlin     7.2             124          70
# 47               Chad Stahelski     7.4             101          20
# 48            Samantha Anderson     8.7             135          80
# 49               Michael Hughes     7.9             120          30
# 50                 Jennifer Lee     8.5             148         150
# 51               David O'Malley     8.2             125          45
# 52               Alex Rodriguez     7.6             130          75
# 53               Sophia Johnson     8.4             140          55
# 54               John McTiernan     8.2             132          28
# 55                 Daniel Patel     7.8             110          40
# 56            Christopher Nolan     9.2             115         100
# 57             Steven Spielberg     8.9             195          22
# 58                 Ryan Coogler     8.9             130          40
#
#     Box Office ($)                  Actor                Actress  \
# 0            321.0            Liam Neeson          Ralph Fiennes
# 1            100.9              Brad Pitt          Edward Norton
# 2            272.7        Anthony Hopkins           Jodie Foster
# 3            120.1           Adrien Brody             Emilia Fox
# 4             46.8         Robert De Niro             Ray Liotta
# 5              4.4        Humphrey Bogart         Ingrid Bergman
# 6            327.3              Brad Pitt         Morgan Freeman
# 7            286.0                    NaN  Michael Clarke Duncan
# 8             44.4         Jack Nicholson         Shelley Duvall
# 9            356.3           Kevin Spacey         Annette Bening
# 10           313.5          Russell Crowe      Jennifer Connelly
# 11           291.5      Leonardo DiCaprio         Jack Nicholson
# 12           172.9          Ralph Fiennes          Tony Revolori
# 13            83.3          Ivana Baquero            Sergi López
# 14            58.0            Tim Robbins         Morgan Freeman
# 15           214.0          John Travolta      Samuel L. Jackson
# 16           678.0              Tom Hanks           Robin Wright
# 17           463.0           Keanu Reeves       Carrie-Anne Moss
# 18          1030.0              Sam Neill             Laura Dern
# 19           775.0            Mark Hamill          Carrie Fisher
# 20           968.0      Matthew Broderick            Moira Kelly
# 21            78.0  Arnold Schwarzenegger                    NaN
# 22           245.0          Marlon Brando              Al Pacino
# 23           214.0          John Travolta      Samuel L. Jackson
# 24           678.0              Tom Hanks           Robin Wright
# 25           463.0           Keanu Reeves       Carrie-Anne Moss
# 26          1030.0              Sam Neill             Laura Dern
# 27           887.0            Elijah Wood           Ian McKellen
# 28          2187.0      Leonardo DiCaprio           Kate Winslet
# 29           775.0            Mark Hamill          Carrie Fisher
# 30          2788.0        Sam Worthington            Zoe Saldana
# 31           968.0      Matthew Broderick            Moira Kelly
# 32            78.0  Arnold Schwarzenegger         Linda Hamilton
# 33           460.0          Russell Crowe        Joaquin Phoenix
# 34          1519.0      Robert Downey Jr.     Scarlett Johansson
# 35           224.0        Jesse Eisenberg            Rooney Mara
# 36           533.0      Leonardo DiCaprio              Tom Hardy
# 37           829.0      Leonardo DiCaprio       Marion Cotillard
# 38            72.0             Jim Carrey           Kate Winslet
# 39           141.0           Bruce Willis                    NaN
# 40          1005.0         Christian Bale           Heath Ledger
# 41           375.0              Tom Hardy        Charlize Theron
# 42           460.0          Russell Crowe        Joaquin Phoenix
# 43           366.0           Bruce Willis           Jeremy Irons
# 44           120.0             Mel Gibson           Danny Glover
# 45           350.0           Keanu Reeves         Sandra Bullock
# 46           240.0           Bruce Willis         Bonnie Bedelia
# 47            88.0           Keanu Reeves       Adrianne Palicki
# 48           450.0        Chris Hemsworth            Zoe Saldana
# 49           210.0           Ryan Gosling             Emma Stone
# 50           720.0           Daisy Ridley            John Boyega
# 51           300.0            Emily Blunt           James McAvoy
# 52           410.0            Tom Holland        Charlize Theron
# 53           380.0            Oscar Isaac        Alicia Vikander
# 54           141.0           Bruce Willis         Bonnie Bedelia
# 55           260.0             Jonah Hill           Rebel Wilson
# 56           400.0     Mathew McConaughey          Anne Hathaway
# 57           321.0            Liam Neeson          Ralph Fiennes
# 58           100.0       Chadwick Boseman         Lupita Nyong'o
#
#            Production Company
# 0          Universal Pictures
# 1            20th Century Fox
# 2              Orion Pictures
# 3              Focus Features
# 4                Warner Bros.
# 5                Warner Bros.
# 6             New Line Cinema
# 7                Warner Bros.
# 8                Warner Bros.
# 9         DreamWorks Pictures
# 10         Universal Pictures
# 11               Warner Bros.
# 12           20th Century Fox
# 13               Picturehouse
# 14  Castle Rock Entertainment
# 15                    Miramax
# 16         Paramount Pictures
# 17               Warner Bros.
# 18         Universal Pictures
# 19           20th Century Fox
# 20       Walt Disney Pictures
# 21             Orion Pictures
# 22         Paramount Pictures
# 23                    Miramax
# 24         Paramount Pictures
# 25               Warner Bros.
# 26         Universal Pictures
# 27            New Line Cinema
# 28           20th Century Fox
# 29           20th Century Fox
# 30           20th Century Fox
# 31       Walt Disney Pictures
# 32             Orion Pictures
# 33        DreamWorks Pictures
# 34             Marvel Studios
# 35          Columbia Pictures
# 36           20th Century Fox
# 37               Warner Bros.
# 38             Focus Features
# 39           20th Century Fox
# 40               Warner Bros.
# 41               Warner Bros.
# 42        DreamWorks Pictures
# 43           20th Century Fox
# 44               Warner Bros.
# 45           20th Century Fox
# 46           20th Century Fox
# 47                  Lionsgate
# 48           20th Century Fox
# 49               Warner Bros.
# 50             Marvel Studios
# 51         Paramount Pictures
# 52             Orion Pictures
# 53            Disney Pictures
# 54           20th Century Fox
# 55         Paramount Pictures
# 56               Warner Bros.
# 57         Universal Pictures
# 58             Marvel Studios

# %% [markdown]
# ## Data Visualization Questions
# For this section, you will leverage the data provided in movies.csv to create visualizations that best display the information each function asks. All necessary import statements are provided. DO NOT import any additional libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# NO SEABORN


def movie_ratings_vs_years(df):
    '''
    Create a line plot of the average movie ratings over the years
    '''
    avg = df.groupby("Year")["Rating"].mean()
    avg.plot()
    plt.title("Avg movie ratings over the years")
    plt.xlabel("Years")
    plt.ylabel("Avg Rating")
    plt.show()


def total_movies_per_production(df):
    '''
    Create a bar graph for the number of movies released by each production company
    '''
    mov = df.groupby("Production Company")["Title"].count()
    mov.plot(kind = "bar")
    plt.title("number of movies released by each production company")
    

    
def drama_action_rating(df):
    '''
    Create a plot that displays the movie 'Rating' between 1990 and 2010 inclusive.
    Plot two lines, one for the genre 'Drama' and the other for the genre 'Action.' 
    Include a legend. Set the xticks to be every 5 years. Provide an appropriate y-label.
    '''
    mask = (df["Year"]>1989)&(df["Year"]<2011)
    df = df[mask].set_index('Year').sort_index()
    drama = df[df["Genre"] == "Drama"]["Rating"]
    Action = df[df["Genre"] == "Action"]["Rating"]

    
    drama.plot(legend = True)
    Action.plot(legend = True)
    plt.title('Ratings for Drama and Action')
    plt.ylabel('Rating')
    plt.xticks(range(1990, 2011,5))

def get_timeseries():
    # create DataFrame with hourly index
    df = pd.DataFrame(index=pd.date_range('2020-01-06', '2023-12-27'))
    
    # add a color
    colors = ['orange', 'green', 'blue']
    df['color'] = [ np.random.choice(colors) for n in range(len(df)) ]

    # add column of values
    df['value'] = df.index.year*120 + df.index.month*12 + np.random.randint(0, 200, size=len(df.index))
    df['value'] = df['value'] + df['color'].apply(lambda c: colors.index(c)*20)
    
    return df

    
def weekly_insight(df):
    '''
    df will be a TimeSeries with two columns, 'color' and 'value'.
    By definition, the TimeSeries is indexed by DateTime.
    Plot two lines on the same plot/figure. 
    The first line is the average monthly value for the color 'blue' across all data.
    The second line is the average monthly value for the color 'orange' across all data.
    Give the plot a title and label the axes.
    Show a legend.
    '''
    orange = df[df["color"] == "orange"]["value"].resample('M').mean()
    blue = df[df["color"] == "blue"]["value"].resample('M').mean()
    orange.plot(legend = True)
    blue.plot(legend = True)
    plt.title("Orange and blue mean across months")
    plt.xlabel("months")
    plt.ylabel("value")
    


def run_visualizations(filename):
    df = pd.read_csv(filename)
    movie_ratings_vs_years(df)
    total_movies_per_production(df)
    drama_action_rating(df)
    weekly_insight(get_timeseries())


run_visualizations('movies.csv')
# Out:
# /tmp/ipykernel_5335/494906947.py:73: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   orange = df[df["color"] == "orange"]["value"].resample('M').mean()
# /tmp/ipykernel_5335/494906947.py:74: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   blue = df[df["color"] == "blue"]["value"].resample('M').mean()

# %% [markdown]
# ##  Algorithmic Questions
#
# You are to solve this question withOUT Pandas.
#
# Let's represent a list of nodes using a dictionary where the key is the node name and the value is a tuple: (next node key, string). They keys for the nodes are strings in the following format: `n#`. For example:  'n1', 'n2', 'n3', 'n4'  ... 'n101', 'n102'.
#
# The first node's key could be 'n1' which might then have the value ('n2', 'Hello'). This would mean that the next node to travel to would be 'n2'. Let's say that 'n2' has the value (None, 'there!'), then our list would be complete because the first Tuple has value `None`.
#
# Write a method, generate_sentence, that accepts two arguments: name of the start node, and the dictionary just described that represents this list of nodes. The method will return the sentence composed by following the nodes to the end.
#
# There is one more twist! If any word appears more than once, exclude the word from the final sentence; it will appear only the first time.
#
# ```python
# # Example usage:
# nodes = {
#     'n1': ('n2', 'My'),
#     'n2': ('n3', 'name'),
#     'n3': ('n4', 'is'),
#     'n4': (None, 'Mr. name Ed!')
# }
#
# sentence = generate_sentence('n1', nodes)
# print(sentence)  # Output: 'My name is Mr. Ed!'
# ```

# %%
def generate_sentence(start_node, nodes):
    seen = set()
    sentence = []
    
    while start_node is not None:
        curr = nodes[start_node]
        for j in curr[1].split():
            if j not in seen:
                seen.add(j)
                sentence.append(j)
        start_node = curr[0]

    return " ".join(sentence)

def test_generate_sentence():
    nodes = {
        'n1': ('n2', 'My'),
        'n2': ('n3', 'name'),
        'n3': ('n4', 'is'),
        'n4': (None, 'Mr. name Ed!')
    }
    print(generate_sentence('n1', nodes))
    
test_generate_sentence()
# Out:
# My name is Mr. Ed!
